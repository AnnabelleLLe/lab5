# %% [markdown]
# 1. What data do you have?
# We have data relating to the correlation between social life and preference of computer science.
# Our questions include:
#
# What Cs-related field do you prefer?
# How many hours per week do you socialize with friends outside of class? (i.e. studying, eating, exercising, lounging, etc.)
# How many clubs are you an active official member in?
# How much do you agree with the following statement: I enjoy meting new people.
# Do you use social media apps to communicate with others?
# What is your major?
# How often do you go to parties per quarter?
# How often do you post on social media?
#
# 2. What would you like to know?
# We want to see if there is a correlation between social life and preference of computer science.

# %%
import pandas as pd
df = pd.read_csv("data2.csv")

test = df[["How many hours per week do you socialize with friends outside of class? (i.e. studying, eating, exercising, lounging, etc.)",
          "How much do you agree with the following statement: I enjoy meeting new people.",
          "How many clubs are you an official active member in?", 
           "How often do you go to parties per quarter?",
           "How often do you post on social media?",
        "What CS-related field do you prefer?" ]]
test.head()
# Out:
#   How many hours per week do you socialize with friends outside of class? (i.e. studying, eating, exercising, lounging, etc.)  \
# 0                                        10-15 hours
# 1                                          0-5 hours
# 2                                          0-5 hours
# 3                                          0-5 hours
# 4                                        10-15 hours
#
#    How much do you agree with the following statement: I enjoy meeting new people.  \
# 0                                                3.0
# 1                                                3.0
# 2                                                4.0
# 3                                                2.0
# 4                                                4.0
#
#    How many clubs are you an official active member in?  \
# 0                                                0.0
# 1                                                0.0
# 2                                                3.0
# ...

# %%
import pandas as pd
df = pd.read_csv("data2.csv")

test = df[["How many hours per week do you socialize with friends outside of class? (i.e. studying, eating, exercising, lounging, etc.)",
          "How much do you agree with the following statement: I enjoy meeting new people.",
          "How many clubs are you an official active member in?", 
           "How often do you go to parties per quarter?",
           "How often do you post on social media?",
        "What CS-related field do you prefer?" ]]
df.drop([40,88]) #cleaned up the empty rows
# Out:
#              Timestamp  \
# 0   11/3/2023 15:26:42
# 1   11/3/2023 15:30:11
# 2   11/3/2023 15:31:28
# 3   11/3/2023 15:31:45
# 4   11/3/2023 15:32:06
# ..                 ...
# 95  11/7/2023 19:16:34
# 96  11/7/2023 22:03:16
# 97   11/8/2023 0:26:22
# 98   11/8/2023 9:23:20
# 99  11/8/2023 14:12:25
#
#    What class are you filling out this survey for? Select all that apply.  \
# 0                                               CS105
# 1                                               CS105
# 2                                               CS105
# 3                                               CS105
# 4                                               CS111
# ..                                                ...
# 95                                              CS105
# 96                                       CS105, CS111
# 97                                              CS105
# 98                                              CS111
# 99                                              CS105
# ...

# %%
import pandas as pd
df = pd.read_csv("data2.csv")

test = df[["How many hours per week do you socialize with friends outside of class? (i.e. studying, eating, exercising, lounging, etc.)",
          "How much do you agree with the following statement: I enjoy meeting new people.",
          "How many clubs are you an official active member in?", 
           "How often do you go to parties per quarter?",
           "How often do you post on social media?",
        "What CS-related field do you prefer?" ]]
test.drop([40,88]) #cleaned up the empty rows 
#fill in the how often do you post on social media w 0's
# Out:
#    How many hours per week do you socialize with friends outside of class? (i.e. studying, eating, exercising, lounging, etc.)  \
# 0                                         10-15 hours
# 1                                           0-5 hours
# 2                                           0-5 hours
# 3                                           0-5 hours
# 4                                         10-15 hours
# ..                                                ...
# 95                                         5-10 hours
# 96                                          0-5 hours
# 97                                         5-10 hours
# 98                                          0-5 hours
# 99                                         5-10 hours
#
#     How much do you agree with the following statement: I enjoy meeting new people.  \
# 0                                                 3.0
# 1                                                 3.0
# ...

# %%
test.loc[:,"How often do you post on social media?"].fillna(0)
# Out:
# 0     1-3 times per week
# 1     1-3 times per week
# 2                      0
# 3     1-3 times per week
# 4     1-3 times per week
#              ...
# 95    1-3 times per week
# 96    1-3 times per week
# 97                     0
# 98    1-3 times per week
# 99    1-3 times per week
# Name: How often do you post on social media?, Length: 100, dtype: object
